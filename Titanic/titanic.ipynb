# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.shape
df['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
df = df.drop(['name', 'sibsp', 'parch', 'ticket', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],axis=1)

# %%
df.describe()
# Out:
#             pclass     survived          age         fare
# count  1309.000000  1309.000000  1046.000000  1308.000000
# mean      2.294882     0.381971    29.881135    33.295479
# std       0.837836     0.486055    14.413500    51.758668
# min       1.000000     0.000000     0.166700     0.000000
# 25%       2.000000     0.000000    21.000000     7.895800
# 50%       3.000000     0.000000    28.000000    14.454200
# 75%       3.000000     1.000000    39.000000    31.275000
# max       3.000000     1.000000    80.000000   512.329200

# %%
df[df['survived'] == 1].describe()
# Out:
#            pclass  survived         age        fare
# count  500.000000     500.0  427.000000  500.000000
# mean     1.962000       1.0   28.918228   49.361184
# std      0.872972       0.0   15.061481   68.648795
# min      1.000000       1.0    0.166700    0.000000
# 25%      1.000000       1.0   20.000000   11.214600
# 50%      2.000000       1.0   28.000000   26.000000
# 75%      3.000000       1.0   38.000000   57.750000
# max      3.000000       1.0   80.000000  512.329200

# %%
df = df.dropna(axis=0)

# %%
df.describe()
# Out:
#             pclass     survived          age         fare
# count  1045.000000  1045.000000  1045.000000  1045.000000
# mean      2.206699     0.408612    29.851834    36.686080
# std       0.841542     0.491813    14.389201    55.732533
# min       1.000000     0.000000     0.166700     0.000000
# 25%       1.000000     0.000000    21.000000     8.050000
# 50%       2.000000     0.000000    28.000000    15.750000
# 75%       3.000000     1.000000    39.000000    35.500000
# max       3.000000     1.000000    80.000000   512.329200

# %%
df['survived'].value_counts()
# Out:
# 0    618
# 1    427
# Name: survived, dtype: int64

# %%
df['pclass'].value_counts()
df['pclass'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['age'].hist()
# Out:
# <AxesSubplot:>

# %%
df.groupby(['sex']).mean()
# Out:
#           pclass  survived        age       fare
# sex
# female  2.048969  0.752577  28.687071  50.308775
# male    2.299848  0.205479  30.539701  28.641019

# %%
df.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.962406  37.037594  111.996900
#        2       0.893204  27.499191   23.267395
#        3       0.473684  22.185307   14.655758
# male   1       0.350993  41.029250   74.818213
#        2       0.145570  30.815401   20.934335
#        3       0.169540  25.863027   12.103374

# %%
df[df['age'] < 18].groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.875000  14.125000  104.083337
#        2       1.000000   8.273150   27.998844
#        3       0.543478   8.416667   18.284148
# male   1       0.857143   9.845243  129.752371
#        2       0.733333   6.222220   31.750280
#        3       0.233333   9.838888   21.677570

# %%
df.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age        fare
# sex    pclass
# female 1       0.962406  37.037594  111.996900
#        2       0.893204  27.499191   23.267395
#        3       0.473684  22.185307   14.655758
# male   1       0.350993  41.029250   74.818213
#        2       0.145570  30.815401   20.934335
#        3       0.169540  25.863027   12.103374

# %%
df[df['survived'] == 1].groupby(['age', 'fare']).mean()
# Out:
#                  pclass  survived
# age     fare
# 0.1667  20.5750     3.0       1.0
# 0.4167  8.5167      3.0       1.0
# 0.6667  14.5000     2.0       1.0
# 0.7500  19.2583     3.0       1.0
# 0.8333  9.3500      3.0       1.0
# ...                 ...       ...
# 63.0000 77.9583     1.0       1.0
# 64.0000 26.5500     1.0       1.0
#         83.1583     1.0       1.0
# 76.0000 78.8500     1.0       1.0
# 80.0000 30.0000     1.0       1.0
#
# [404 rows x 2 columns]
